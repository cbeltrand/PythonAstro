# %%
'''Script guía'''

from math import sqrt
xvals = range(150)
yvals = range(100)

xcenter = 25
ycenter = 60

image = []
for j in yvals:
    line = []
    yv = (j-ycenter)
    for i in xvals:
        xv = (i-xcenter)
        line.append( sqrt( xv*xv + yv*yv))
    image.append(line)

#print(image, "\n N:", len(line))
# Do a plot of the nested lists generated.
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, dpi=(120),subplot_kw={'aspect':'equal'})
v = ax.imshow(image, origin='lower')
cbar = fig.colorbar(v)
cbar.set_label("Radius")
ax.plot(xcenter, ycenter, 'wx', ms=3)
ax.text(xcenter, ycenter, "Center", color='w')
ax.set_xlabel('X')
ax.set_ylabel("Y")
ax.set_title("Gradient");

# %%
'''listas de comprensión'''

xvals = range(150)
yvals = range(100)

from math import sqrt

xcenter = 25
ycenter = 60


#print(yv)
yv = [j-ycenter for j in yvals]
xv = [i-xcenter for i in xvals]
line = [[sqrt(a*a + b*b) for b in xv ] for a in yv ]
#line = [sqrt(a*a + b*b) for a,b in zip(yv,xv)] NO funciona

# %%
fig, ax = plt.subplots(1,1, dpi=(120),subplot_kw={'aspect':'equal'})
#v = ax.imshow(line, origin='lower')
v = ax.imshow(line, origin='lower')
cbar = fig.colorbar(v)
cbar.set_label("Radius")
ax.plot(xcenter, ycenter, 'wx', ms=3)
ax.text(xcenter, ycenter, "Center", color='w')
ax.set_xlabel('X')
ax.set_ylabel("Y")
ax.set_title("Gradient");
